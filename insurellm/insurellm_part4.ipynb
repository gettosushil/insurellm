# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.29420493957109245, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/llms/openai/openai.py:814, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     813             else:
# --> 814                 raise e
#     815 except OpenAIError as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/llms/openai/openai.py:724, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     723     raise OpenAIError(status_code=422, message="max retries must be an int")
# --> 724 openai_client: OpenAI = self._get_openai_client(
#     725     is_async=False,
#     726     api_key=api_key,
#     727     api_base=api_base,
#     728     api_version=api_version,
#     729     timeout=timeout,
#     730     max_retries=max_retries,
#     731     organization=organization,
#     732     client=client,
#     733 )
#     735 ## LOGGING
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/llms/openai/openai.py:382, in OpenAIChatCompletion._get_openai_client(self, is_async, api_key, api_base, api_version, timeout, max_retries, organization, client, shared_session)
#     381 else:
# --> 382     _new_client = OpenAI(
#     383         api_key=api_key,
#     384         base_url=api_base,
#     385         http_client=http_client,
#     386         timeout=timeout,
#     387         max_retries=max_retries,
#     388         organization=organization,
#     389     )
#     391 ## SAVE CACHE KEY
#
# File /opt/anaconda3/lib/python3.12/site-packages/openai/_client.py:230, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     222 if (
#     223     provider_runtime is None
#     224     and _enforce_credentials
#    (...)
#     228     and self.admin_api_key is None
#     229 ):
# --> 230     raise OpenAIError(
#     231         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     232     )
#     234 if organization is None and provider_runtime is None:
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/main.py:5717, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, include_server_side_tool_invocations, deployment_id, extra_headers, safety_identifier, service_tier, store, prompt_cache_key, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, enable_json_schema_validation, **kwargs)
#    5691 elif (
#    5692     # A known OpenAI model name only decides the route when nothing else
#    5693     # resolved a provider. get_llm_provider() already maps these names to
#    (...)
#    5715     # note: if a user sets a custom base - we should ensure this works
#    5716     # allow for the setting of dynamic and stateful api-bases
# -> 5717     response = _complete_custom_openai(_dispatch_ctx)
#    5719 elif custom_llm_provider == "mistral":
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/main.py:2620, in _complete_custom_openai(ctx)
#    2614     logging.post_call(
#    2615         input=messages,
#    2616         api_key=api_key,
#    2617         original_response=str(e),
#    2618         additional_args={"headers": headers},
#    2619     )
# -> 2620     raise e
#    2622 if optional_params.get("stream", False):
#    2623     ## LOGGING
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/main.py:2592, in _complete_custom_openai(ctx)
#    2591     else:
# -> 2592         response = openai_chat_completions.completion(
#    2593             model=model,
#    2594             messages=messages,
#    2595             headers=headers,
#    2596             model_response=model_response,
#    2597             print_verbose=print_verbose,
#    2598             api_key=api_key,
#    2599             api_base=api_base,
#    2600             acompletion=acompletion,
#    2601             logging_obj=logging,
#    2602             optional_params=optional_params,
#    2603             litellm_params=litellm_params,
#    2604             logger_fn=logger_fn,
#    2605             timeout=timeout,
#    2606             custom_prompt_dict=custom_prompt_dict,
#    2607             client=client,  # pass AsyncOpenAI, OpenAI client
#    2608             organization=organization,
#    2609             custom_llm_provider=custom_llm_provider,
#    2610             shared_session=shared_session,
#    2611         )
#    2612 except Exception as e:
#    2613     ## LOGGING - log the original exception returned
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/llms/openai/openai.py:825, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     824     error_headers = getattr(error_response, "headers", None)
# --> 825 raise OpenAIError(
#     826     status_code=status_code,
#     827     message=error_text,
#     828     headers=error_headers,
#     829     body=error_body,
#     830 )
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
#
# During handling of the above exception, another exception occurred:
#
# InternalServerError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File ~/projects/llm_engineering/insurellm/evaluation/eval.py:156, in evaluate_answer(test)
#     130 judge_messages = [
#     131     {
#     132         "role": "system",
#    (...)
#     152     },
#     153 ]
#     155 # Call LLM judge with structured outputs (async)
# --> 156 judge_response = completion(model=MODEL, messages=judge_messages, response_format=AnswerEval)
#     158 answer_eval = AnswerEval.model_validate_json(judge_response.choices[0].message.content)
#     160 return answer_eval, generated_answer, retrieved_docs
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/utils.py:1745, in client.<locals>.wrapper(*args, **kwargs)
#    1741 if logging_obj:
#    1742     logging_obj.failure_handler(
#    1743         e, traceback_exception, start_time, end_time
#    1744     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1745 raise e
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/utils.py:1591, in client.<locals>.wrapper(*args, **kwargs)
#    1589         print_verbose(f"Error while checking max token limit: {e}")
#    1590 # MODEL CALL
# -> 1591 result = original_function(*args, **kwargs)
#    1592 end_time = datetime.datetime.now()
#    1593 if _is_streaming_request(
#    1594     kwargs=kwargs,
#    1595     call_type=call_type,
#    1596 ):
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/main.py:5837, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, include_server_side_tool_invocations, deployment_id, extra_headers, safety_identifier, service_tier, store, prompt_cache_key, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, enable_json_schema_validation, **kwargs)
#    5834     return response
#    5835 except Exception as e:
#    5836     ## Map to OpenAI Exception
# -> 5837     raise exception_type(
#    5838         model=model,
#    5839         custom_llm_provider=custom_llm_provider,
#    5840         original_exception=e,
#    5841         completion_kwargs=args,
#    5842         extra_kwargs=kwargs,
#    5843     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2675, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2673     if isinstance(e, error_type):
#    2674         setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2675         raise e  # it's already mapped
#    2676 raised_exc: Final = APIConnectionError(
#    2677     message=f"{original_exception}\n{_redact_string(traceback.format_exc())}",
#    2678     llm_provider="",
#    2679     model="",
#    2680 )
#    2681 setattr(raised_exc, "litellm_response_headers", litellm_response_headers)
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2436, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2422     extract_and_raise_litellm_exception(
#    2423         response=getattr(original_exception, "response", None),
#    2424         error_str=error_str,
#    2425         model=model,
#    2426         custom_llm_provider=custom_llm_provider,
#    2427     )
#    2428 if (
#    2429     custom_llm_provider == "openai"
#    2430     or custom_llm_provider == "text-completion-openai"
#    (...)
#    2434     or custom_llm_provider == "runwayml"
#    2435 ):
# -> 2436     _map_openai_exception(
#    2437         model=model,
#    2438         original_exception=mappable_exception,
#    2439         custom_llm_provider=custom_llm_provider,
#    2440         error_str=error_str,
#    2441         exception_type=exception_type,
#    2442         exception_provider=exception_provider,
#    2443         extra_information=extra_information,
#    2444     )
#    2445 elif custom_llm_provider == "anthropic" or custom_llm_provider == "anthropic_text":  # one of the anthropics
#    2446     _map_anthropic_exception(
#    2447         model=model,
#    2448         original_exception=mappable_exception,
#    (...)
#    2453         extra_information=extra_information,
#    2454     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:449, in _map_openai_exception(model, original_exception, custom_llm_provider, error_str, exception_type, exception_provider, extra_information)
#     441     raise RateLimitError(
#     442         message=f"RateLimitError: {exception_provider} - {message}",
#     443         model=model,
#    (...)
#     446         litellm_debug_info=extra_information,
#     447     )
#     448 elif original_exception.status_code == 500:
# --> 449     raise InternalServerError(
#     450         message=f"InternalServerError: {exception_provider} - {message}",
#     451         model=model,
#     452         llm_provider=custom_llm_provider,
#     453         response=getattr(original_exception, "response", None),
#     454         litellm_debug_info=extra_information,
#     455     )
#     456 elif original_exception.status_code == 502:
#     457     raise BadGatewayError(
#     458         message=f"BadGatewayError: {exception_provider} - {message}",
#     459         model=model,
#    (...)
#     462         litellm_debug_info=extra_information,
#     463     )
#
# InternalServerError: litellm.InternalServerError: InternalServerError: OpenAIException - Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
